# %%
import pandas as pd
import numpy as np
import plotly.express as px
import nbformat
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Traduction des colonnes des données

# %%
ensemble_clients_olist  = pd.read_csv('data/olist_customers_dataset.csv')
ensemble_geolocalisation_olist = pd.read_csv('data/olist_geolocation_dataset.csv')
ensemble_articles_commandes_olist = pd.read_csv('data/olist_order_items_dataset.csv')
ensemble_paiements_commandes_olist = pd.read_csv('data/olist_order_payments_dataset.csv')
ensemble_avis_commandes_olist = pd.read_csv('data/olist_order_reviews_dataset.csv')
ensemble_commandes_olist = pd.read_csv('data/olist_orders_dataset.csv')
ensemble_produits_olist = pd.read_csv('data/olist_products_dataset.csv')
ensemble_vendeurs_olist = pd.read_csv('data/olist_sellers_dataset.csv')
traduction_nom_categorie_produit = pd.read_csv('data/product_category_name_translation.csv')

# %%
ensemble_clients_olist_dict = {
    'customer_id': 'identifiant_client',
    'customer_unique_id': 'identifiant_unique_client',
    'customer_zip_code_prefix': 'prefixe_code_postal_client',
    'customer_city': 'ville_client',
    'customer_state': 'etat_client'
}

# %%
ensemble_clients_olist = ensemble_clients_olist.rename(columns=ensemble_clients_olist_dict)

# %%
ensemble_clients_olist.head()
# Out:
#                  identifiant_client         identifiant_unique_client  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    prefixe_code_postal_client           ville_client etat_client
# 0                       14409                 franca          SP
# 1                        9790  sao bernardo do campo          SP
# 2                        1151              sao paulo          SP
# 3                        8775        mogi das cruzes          SP
# 4                       13056               campinas          SP

# %%
ensemble_geolocalisation_olist_dict = {
    'geolocation_zip_code_prefix': 'prefixe_code_postal_geolocalisation',
    'geolocation_lat': 'latitude_geolocalisation',
    'geolocation_lng': 'longitude_geolocalisation',
    'geolocation_city': 'ville_geolocalisation',
    'geolocation_state': 'etat_geolocalisation'
}

# %%
ensemble_geolocalisation_olist = ensemble_geolocalisation_olist.rename(columns=ensemble_geolocalisation_olist_dict)

# %%
ensemble_geolocalisation_olist.head()
# Out:
#    prefixe_code_postal_geolocalisation  latitude_geolocalisation  \
# 0                                 1037                -23.545621
# 1                                 1046                -23.546081
# 2                                 1046                -23.546129
# 3                                 1041                -23.544392
# 4                                 1035                -23.541578
#
#    longitude_geolocalisation ville_geolocalisation etat_geolocalisation
# 0                 -46.639292             sao paulo                   SP
# 1                 -46.644820             sao paulo                   SP
# 2                 -46.642951             sao paulo                   SP
# 3                 -46.639499             sao paulo                   SP
# 4                 -46.641607             sao paulo                   SP

# %%
ensemble_articles_commandes_olist_dict = {
    'order_id': 'identifiant_commande',
    'order_item_id': 'identifiant_article_commande',
    'product_id': 'identifiant_produit',
    'seller_id': 'identifiant_vendeur',
    'shipping_limit_date': 'date_limite_expedition',
    'price': 'prix',
    'freight_value': 'valeur_fret'
}

# %%
ensemble_articles_commandes_olist = ensemble_articles_commandes_olist.rename(columns=ensemble_articles_commandes_olist_dict)

# %%
ensemble_articles_commandes_olist.head()
# Out:
#                identifiant_commande  identifiant_article_commande  \
# 0  00010242fe8c5a6d1ba2dd792cb16214                             1
# 1  00018f77f2f0320c557190d7a144bdd3                             1
# 2  000229ec398224ef6ca0657da4fc703e                             1
# 3  00024acbcdf0a6daa1e931b038114c75                             1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9                             1
#
#                 identifiant_produit               identifiant_vendeur  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   date_limite_expedition    prix  valeur_fret
# 0    2017-09-19 09:45:35   58.90        13.29
# 1    2017-05-03 11:05:13  239.90        19.93
# ...

# %%
ensemble_paiements_commandes_olist_dict= {
    'order_id': 'identifiant_commande',
    'payment_sequential': 'sequence_paiement',
    'payment_type': 'type_paiement',
    'payment_installments': 'versements_paiement',
    'payment_value': 'valeur_paiement'
}

# %%
ensemble_paiements_commandes_olist = ensemble_paiements_commandes_olist.rename(columns=ensemble_paiements_commandes_olist_dict)

# %%
ensemble_paiements_commandes_olist.head()
# Out:
#                identifiant_commande  sequence_paiement type_paiement  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                  1   credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                  1   credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                  1   credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                  1   credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                  1   credit_card
#
#    versements_paiement  valeur_paiement
# 0                    8            99.33
# 1                    1            24.39
# 2                    1            65.71
# 3                    8           107.78
# 4                    2           128.45

# %%
ensemble_paiements_commandes_olist.shape
# Out:
# (103886, 5)

# %%
ensemble_avis_commandes_olist_dict = {
    'review_id': 'identifiant_avis',
    'order_id': 'identifiant_commande',
    'review_score': 'score_avis',
    'review_comment_title': 'titre_commentaire_avis',
    'review_comment_message': 'message_commentaire_avis',
    'review_creation_date': 'date_creation_avis',
    'review_answer_timestamp': 'timestamp_reponse_avis'
}

# %%
ensemble_avis_commandes_olist = ensemble_avis_commandes_olist.rename(columns = ensemble_avis_commandes_olist_dict)

# %%
ensemble_avis_commandes_olist.head()
# Out:
#                    identifiant_avis              identifiant_commande  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    score_avis titre_commentaire_avis  \
# 0           4                    NaN
# 1           5                    NaN
# 2           5                    NaN
# 3           5                    NaN
# 4           5                    NaN
#
#                             message_commentaire_avis   date_creation_avis  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
ensemble_commandes_olist_dict = {
    'order_id': 'identifiant_commande',
    'customer_id': 'identifiant_client',
    'order_status': 'statut_commande',
    'order_purchase_timestamp': 'timestamp_achat_commande',
    'order_approved_at': 'commande_approuvee_a',
    'order_delivered_carrier_date': 'date_livraison_transporteur_commande',
    'order_delivered_customer_date': 'date_livraison_client_commande',
    'order_estimated_delivery_date': 'date_livraison_estimee_commande'
}

# %%
ensemble_commandes_olist = ensemble_commandes_olist.rename(columns=ensemble_commandes_olist_dict)

# %%
ensemble_commandes_olist.head()
# Out:
#                identifiant_commande                identifiant_client  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   statut_commande timestamp_achat_commande commande_approuvee_a  \
# 0       delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1       delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2       delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3       delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4       delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   date_livraison_transporteur_commande date_livraison_client_commande  \
# 0                  2017-10-04 19:55:00            2017-10-10 21:25:13
# ...

# %%
ensemble_produits_olist_dict = {
    'product_id': 'identifiant_produit',
    'product_category_name': 'nom_categorie_produit',
    'product_name_lenght': 'longueur_nom_produit',
    'product_description_lenght': 'longueur_description_produit',
    'product_photos_qty': 'quantite_photos_produit',
    'product_weight_g': 'poids_produit_g',
    'product_length_cm': 'longueur_produit_cm',
    'product_height_cm': 'hauteur_produit_cm',
    'product_width_cm': 'largeur_produit_cm'
}

# %%
ensemble_produits_olist = ensemble_produits_olist.rename(columns=ensemble_produits_olist_dict)

# %%
ensemble_produits_olist.head()
# Out:
#                 identifiant_produit  nom_categorie_produit  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    longueur_nom_produit  longueur_description_produit  \
# 0                  40.0                         287.0
# 1                  44.0                         276.0
# 2                  46.0                         250.0
# 3                  27.0                         261.0
# 4                  37.0                         402.0
#
#    quantite_photos_produit  poids_produit_g  longueur_produit_cm  \
# 0                      1.0            225.0                 16.0
# 1                      1.0           1000.0                 30.0
# 2                      1.0            154.0                 18.0
# ...

# %%
ensemble_vendeurs_olist_dict = {
    'seller_id': 'identifiant_vendeur',
    'seller_zip_code_prefix': 'prefixe_code_postal_vendeur',
    'seller_city': 'ville_vendeur',
    'seller_state': 'etat_vendeur'
}

# %%
ensemble_vendeurs_olist = ensemble_vendeurs_olist.rename(columns=ensemble_vendeurs_olist_dict)

# %%
ensemble_vendeurs_olist.head()
# Out:
#                 identifiant_vendeur  prefixe_code_postal_vendeur  \
# 0  3442f8959a84dea7ee197c632cb2df15                        13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                        13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                        20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                         4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                        12914
#
#        ville_vendeur etat_vendeur
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
traduction_nom_categorie_produit_dict = {
    'product_category_name': 'nom_categorie_produit',
    'product_category_name_english': 'nom_categorie_produit_anglais'
}

# %%
traduction_nom_categorie_produit =traduction_nom_categorie_produit.rename(columns=traduction_nom_categorie_produit_dict)

# %%
traduction_nom_categorie_produit.head()
# Out:
#     nom_categorie_produit nom_categorie_produit_anglais
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %% [markdown]
# ## Pre processing

# %% [markdown]
# Liste des fonctions

# %%
def joindre_deux_Dataframe(df1,df2):
    """joindre deux Dataframe

    Args:
        df1 (Dataframe): df1
        df2 (Dataframe): df2

    Returns:
        Dataframe: _description_
    """
    jointure = pd.merge(df1,df2,how='inner')
    return jointure

# %%
def suprimmer_les_doublons(liste_datas):
    """suprimmer_les_doublons

    Args:
        liste_datas (liste): listes des Dataframes
    """
    for data in liste_datas:
        data.drop_duplicates()

# %%
def calculer_les_indices_de_dispertions(data,target):
    """Calculer les indices de dispertions
    Args:
        data (Dataframe): dataset à traiter
        target (str): colonne à traiter

    Returns:
        tuple: indice_dispertion_positive,indice_dispertion_négative
    """
    indice_dispertion_positive = 1.5 * (data[target].quantile(q=0.75 - 0.25))
    indice_dispertion_négative = -1.5 * (data[target].quantile(q=0.75 - 0.25))
    return indice_dispertion_positive,indice_dispertion_négative

# %%
def créer_un_sous_ensemble_de_données(data,target):
    """Calculer les indices de dispertions
    Args:
        data (Dataframe): dataset à traiter
        target (str): colonne à traiter

    Returns:
        Dataframe: indice_dispertion_positive,indice_dispertion_négative
    """
    indice_dispertion_positive,indice_dispertion_négative = calculer_les_indices_de_dispertions(data,target)
    data_sub = data[~((data[target] > indice_dispertion_positive) | (data[target] < indice_dispertion_négative))] 
    return data_sub

# %%
def remplacer_les_valeurs_extrèmes_par_des_NaN(data,target):
    """Remplacer les valeurs extrèmes par des NaN
    Args:
        data (Dataframe): dataset à traiter
        target (str): colonne à traiter
    """
    indice_dispertion_positive,indice_dispertion_négative = calculer_les_indices_de_dispertions(data,target)
    condition = (data[target] > indice_dispertion_positive) | (data[target] < indice_dispertion_négative)
    data.loc[condition, target] = np.nan

# %%
def découpage_train_test(data,target,feature):
    """découpage train test
    Args:
        data (Dataframe): dataset à traiter
        target (str): colonne à traiter
    Returns:
        tuple: X_train, X_test, y_train, y_test
    """
    x = data[target].to_numpy()
    y = data[feature].to_numpy()
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
    return X_train, X_test, y_train, y_test

# %%
def entrainer_régression_linéaire_et_prédire(data,target,feature):
    """Entrainer régression linéaire et prédire
    Args:
        data (Dataframe): dataset à traiter
        target (str): colonne à traiter
    Returns:
        tuple: coeffs,y_pred, mse
    """
    X, y, = découpage_train_test(data,target,feature)[0], découpage_train_test(data,target,feature)[2]
    coeffs = np.polyfit(X, y, 1)
    y_pred = np.polyval(coeffs,X)
    y_pred = pd.Series(y_pred)
    mse = np.mean(y - y_pred)**2
    fig = px.scatter(
    x=X, y=y_pred, opacity=0.65,
    trendline='ols', trendline_color_override='darkblue'
    )
    fig.show()
    return coeffs,y_pred, mse

# %%
def tester_régression_linéaire_et_prédire(data,target,feature,coeffs):
    """Tester régression linéaire et prédire
      Args:
        data (Dataframe): dataset à traiter
        target (str): colonne à traiter
    Returns:
        tuple: y_pred, mse
    """
    X, y, = découpage_train_test(data,target,feature)[1], découpage_train_test(data,target,feature)[3]
    y_pred = np.polyval(coeffs,X)
    y_pred = pd.Series(y_pred)
    mse = np.mean(y - y_pred)**2
    fig = px.scatter(
    x=X, y=y_pred, opacity=0.65,
    trendline='ols', trendline_color_override='darkblue'
    )
    fig.show()
    return y_pred, mse

# %%
def remplacer_les_NaN_par_des_prédictions(data,target,feature,coeffs):
    """remplacer les NaN par des prédictions
      Args:
        data (Dataframe): dataset à traiter
        target (str): colonne à traiter
        feature (str): colonne à traiter
        coeffs (ndarray): coefficients a et b
    """
    predictions = np.polyval(coeffs, data[feature])
    predictions = pd.Series(data=predictions)
    data.fillna({target: predictions}, inplace=True)

# %%
def afficher_graphique_corrélation(data):
    """afficher graphique corrélation
      Args:
        data (Dataframe): dataset à traiter
    """
    fig = px.imshow(data.corr(), text_auto=True)
    fig.show()

# %%
def normalize_data(data, min_range=0, max_range=1):
    """
    Normalizes a given pandas Series or DataFrame column.
    Normalise les données d'une colonne du DataFrame
    Args :
    data (pandas.Series or pandas.DataFrame): The data to be normalized.
    min_range (float): Minimum de valeur à désirer. Default is 0.
    max_range (float): Maximum de valeur à désirer Default is 1.

    Returns:
    Normalized data.
    """
    min_val = data.min()
    max_val = data.max()
    normalized_data = (data - min_val) * (max_range - min_range) / (max_val - min_val) + min_range
    return normalized_data

# %% [markdown]
# Supprimer les doublons

# %%
liste_dfs = [
    ensemble_clients_olist,
    ensemble_geolocalisation_olist,
    ensemble_articles_commandes_olist,
    ensemble_paiements_commandes_olist,
    ensemble_avis_commandes_olist,
    ensemble_commandes_olist,
    ensemble_produits_olist,
    ensemble_vendeurs_olist,
    traduction_nom_categorie_produit
]

suprimmer_les_doublons(liste_datas=liste_dfs)

# %% [markdown]
# Jointures

# %%
répartition_des_niveaux_de_frais_et_livraison = joindre_deux_Dataframe(df1=ensemble_articles_commandes_olist,df2=ensemble_commandes_olist)
répartition_des_niveaux_de_frais_et_livraison = répartition_des_niveaux_de_frais_et_livraison[['date_livraison_client_commande','identifiant_client','statut_commande','valeur_fret']]
répartition_des_niveaux_de_frais_et_livraison['date_livraison_client_commande'] = pd.to_datetime(répartition_des_niveaux_de_frais_et_livraison['date_livraison_client_commande'])
répartition_des_niveaux_de_frais_et_livraison['annee_livraison'] = répartition_des_niveaux_de_frais_et_livraison["date_livraison_client_commande"].dt.year.fillna(0).astype(int)
répartition_des_niveaux_de_frais_et_livraison['mois_livraison_client'] = répartition_des_niveaux_de_frais_et_livraison['date_livraison_client_commande'].dt.month.fillna(0).astype(int)
répartition_des_niveaux_de_frais_et_livraison = répartition_des_niveaux_de_frais_et_livraison[['date_livraison_client_commande','annee_livraison','mois_livraison_client','identifiant_client','statut_commande','valeur_fret']]
répartition_des_niveaux_de_frais_et_livraison = répartition_des_niveaux_de_frais_et_livraison.rename(columns={'valeur_fret':'frais_transport'})

# %% [markdown]
# Normalisation des frais de transport entre 100 à 250

# %%
répartition_des_niveaux_de_frais_et_livraison["frais_transport"] = normalize_data(répartition_des_niveaux_de_frais_et_livraison["frais_transport"],min_range=100,max_range=250)

# %% [markdown]
# Ajout de la colonne catégories de frais de livraison

# %%
 #On définit les plages de valeurs de frais entre 100 à 250  
seuils = [100,150,200,250] 
# Définition des catégories de frais en fonction des plages
categories = ['bas', 'milieu', 'élevés']

# Assigner une catégorie à chaque ligne en fonction de la valeur de 'valeur_fret'
répartition_des_niveaux_de_frais_et_livraison['categorie_frais'] = pd.cut(répartition_des_niveaux_de_frais_et_livraison['frais_transport'], bins=seuils, labels=categories, right=False)

# %%
répartition_des_niveaux_de_frais_et_livraison.head()
# Out:
#   date_livraison_client_commande  annee_livraison  mois_livraison_client  \
# 0            2017-09-20 23:43:48             2017                      9
# 1            2017-05-12 16:04:24             2017                      5
# 2            2018-01-22 13:19:16             2018                      1
# 3            2018-08-14 13:32:39             2018                      8
# 4            2017-03-01 16:42:31             2017                      3
#
#                  identifiant_client statut_commande  frais_transport  \
# 0  3ce436f183e68e07877b285a838db11a       delivered       104.865993
# 1  f6dd3ec061db4e3987629fe6b26e5cce       delivered       107.297159
# 2  6489ae5e4333f3693df5ad4372dab6d3       delivered       106.542912
# 3  d4eb9395c8c0431ee92fce09860c5a06       delivered       104.682923
# 4  58dbd0b2d70206bf40e62cd34e84d795       delivered       106.641769
#
#   categorie_frais
# 0             bas
# 1             bas
# 2             bas
# 3             bas
# ...

# %%
ensemble_geolocalisation_olist.head()
# Out:
#    prefixe_code_postal_geolocalisation  latitude_geolocalisation  \
# 0                                 1037                -23.545621
# 1                                 1046                -23.546081
# 2                                 1046                -23.546129
# 3                                 1041                -23.544392
# 4                                 1035                -23.541578
#
#    longitude_geolocalisation ville_geolocalisation etat_geolocalisation
# 0                 -46.639292             sao paulo                   SP
# 1                 -46.644820             sao paulo                   SP
# 2                 -46.642951             sao paulo                   SP
# 3                 -46.639499             sao paulo                   SP
# 4                 -46.641607             sao paulo                   SP

# %%
ensemble_clients_olist.head()
# Out:
#                  identifiant_client         identifiant_unique_client  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    prefixe_code_postal_client           ville_client etat_client
# 0                       14409                 franca          SP
# 1                        9790  sao bernardo do campo          SP
# 2                        1151              sao paulo          SP
# 3                        8775        mogi das cruzes          SP
# 4                       13056               campinas          SP

# %%
total_chiffre_d_affaire = joindre_deux_Dataframe(df1=ensemble_produits_olist,df2=ensemble_articles_commandes_olist)
total_chiffre_d_affaire = total_chiffre_d_affaire[['quantite_photos_produit','prix']]
total_chiffre_d_affaire['chiffre_affaire'] = total_chiffre_d_affaire['quantite_photos_produit'] * total_chiffre_d_affaire['prix']
total_chiffre_d_affaire = total_chiffre_d_affaire.rename(columns={'quantite_photos_produit':'quantité_produits'})

# %%
total_chiffre_d_affaire.shape
# Out:
# (112650, 3)

# %%
total_chiffre_d_affaire.isna().sum()
# Out:
# quantité_produits    1603
# prix                    0
# chiffre_affaire      1603
# dtype: int64

# %%
total_chiffre_d_affaire.head()
# Out:
#    quantité_produits    prix  chiffre_affaire
# 0                1.0   10.91            10.91
# 1                1.0  248.00           248.00
# 2                1.0   79.80            79.80
# 3                1.0  112.30           112.30
# 4                4.0   37.90           151.60

# %%
afficher_graphique_corrélation(total_chiffre_d_affaire)

# %%
total_chiffre_d_affaire_sub = total_chiffre_d_affaire.dropna()

# %%
total_chiffre_d_affaire_sub_train = entrainer_régression_linéaire_et_prédire(data=total_chiffre_d_affaire_sub,target='chiffre_affaire',feature='prix')

# %%
total_chiffre_d_affaire_coeffs = total_chiffre_d_affaire_sub_train[0]
total_chiffre_d_affaire_sub_prédictions_train = total_chiffre_d_affaire_sub_train[1]
total_chiffre_d_affaire_sub_mse_train = total_chiffre_d_affaire_sub_train[2]

# %%
total_chiffre_d_affaire_coeffs
# Out:
# array([ 0.22580913, 56.95692957])

# %%
total_chiffre_d_affaire_sub_mse_train
# Out:
# 1.8254577651115367e-25

# %%
total_chiffre_d_affaire_sub_prédictions_train
# Out:
# 0        110.473694
# 1         71.115162
# 2         80.432047
# 3         79.312034
# 4         72.761311
#             ...
# 88832     60.567618
# 88833    120.860914
# 88834     64.293468
# 88835    101.892947
# 88836     79.492681
# Length: 88837, dtype: float64

# %%
total_chiffre_d_affaire_sub_test = tester_régression_linéaire_et_prédire(data=total_chiffre_d_affaire_sub,
                                                                         target='chiffre_affaire',
                                                                         feature='prix',
                                                                         coeffs=total_chiffre_d_affaire_coeffs)

# %%
total_chiffre_d_affaire_sub_mse_test = total_chiffre_d_affaire_sub_test[1]

# %%
total_chiffre_d_affaire_sub_mse_test
# Out:
# 0.49143094414964306

# %%
remplacer_les_NaN_par_des_prédictions(data=total_chiffre_d_affaire,
                                      target='chiffre_affaire',
                                      feature='prix',
                                      coeffs=total_chiffre_d_affaire_coeffs
                                      )

# %%
total_chiffre_d_affaire.fillna({'quantité_produits': total_chiffre_d_affaire['prix']/total_chiffre_d_affaire['chiffre_affaire']}, inplace=True)

# %%
total_chiffre_d_affaire.head()
# Out:
#    quantité_produits    prix  chiffre_affaire
# 0                1.0   10.91            10.91
# 1                1.0  248.00           248.00
# 2                1.0   79.80            79.80
# 3                1.0  112.30           112.30
# 4                4.0   37.90           151.60

# %%
total_chiffre_d_affaire.isna().sum()
# Out:
# quantité_produits    0
# prix                 0
# chiffre_affaire      0
# dtype: int64

# %%
ensemble_geolocalisation_olist = ensemble_geolocalisation_olist.rename(columns={'prefixe_code_postal_geolocalisation':'prefixe_code_postal_client'})
ensemble_clients_olist['prefixe_code_postal_client'] = ensemble_clients_olist['prefixe_code_postal_client'].astype(str)
ensemble_geolocalisation_olist['prefixe_code_postal_client'] = ensemble_geolocalisation_olist['prefixe_code_postal_client'].astype(str)
customer_geolocation = joindre_deux_Dataframe(df1=ensemble_clients_olist,df2=ensemble_geolocalisation_olist)

# %%
customer_geolocation = customer_geolocation.drop(columns=['identifiant_unique_client','ville_geolocalisation','etat_geolocalisation'])

# %%
customer_geolocation.head()
# Out:
#                  identifiant_client prefixe_code_postal_client ville_client  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7                      14409       franca
# 1  06b8999e2fba1a1fbc88172c00ba8bc7                      14409       franca
# 2  06b8999e2fba1a1fbc88172c00ba8bc7                      14409       franca
# 3  06b8999e2fba1a1fbc88172c00ba8bc7                      14409       franca
# 4  06b8999e2fba1a1fbc88172c00ba8bc7                      14409       franca
#
#   etat_client  latitude_geolocalisation  longitude_geolocalisation
# 0          SP                -20.509897                 -47.397866
# 1          SP                -20.497396                 -47.399241
# 2          SP                -20.510459                 -47.399553
# 3          SP                -20.480940                 -47.394161
# 4          SP                -20.515413                 -47.398194

# %%
customer_geolocation.isna().sum()
# Out:
# identifiant_client            0
# prefixe_code_postal_client    0
# ville_client                  0
# etat_client                   0
# latitude_geolocalisation      0
# longitude_geolocalisation     0
# dtype: int64

# %%
customer_geolocation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15083455 entries, 0 to 15083454
# Data columns (total 6 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   identifiant_client          object
#  1   prefixe_code_postal_client  object
#  2   ville_client                object
#  3   etat_client                 object
#  4   latitude_geolocalisation    float64
#  5   longitude_geolocalisation   float64
# dtypes: float64(2), object(4)
# memory usage: 690.5+ MB

# %%
payments_orders = joindre_deux_Dataframe(df1=ensemble_paiements_commandes_olist,df2=ensemble_commandes_olist)
payments_orders = payments_orders.drop(columns=['sequence_paiement',
                                                'versements_paiement',
                                                'statut_commande',
                                                'commande_approuvee_a',
                                                'date_livraison_transporteur_commande',
                                                'date_livraison_client_commande',
                                                'date_livraison_estimee_commande'
                                                ])

# %%
payments_orders.head()
# Out:
#                identifiant_commande type_paiement  valeur_paiement  \
# 0  b81ef226f3fe1789b1e8b2acac839d17   credit_card            99.33
# 1  a9810da82917af2d9aefd1278f1dcfa0   credit_card            24.39
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd   credit_card            65.71
# 3  ba78997921bbcdc1373bb41e913ab953   credit_card           107.78
# 4  42fdf880ba16b47b59251dd489d4441a   credit_card           128.45
#
#                  identifiant_client timestamp_achat_commande
# 0  0a8556ac6be836b46b3e89920d59291c      2018-04-25 22:01:49
# 1  f2c7fc58a9de810828715166c672f10a      2018-06-26 11:01:38
# 2  25b14b69de0b6e184ae6fe2755e478f9      2017-12-12 11:19:55
# 3  7a5d8efaaa1081f800628c30d2b0728f      2017-12-06 12:04:06
# 4  15fd6fb8f8312dbb4674e4518d6fa3b3      2018-05-21 13:59:17

# %%
payments_orders.isna().sum()
# Out:
# identifiant_commande        0
# type_paiement               0
# valeur_paiement             0
# identifiant_client          0
# timestamp_achat_commande    0
# dtype: int64

# %%
order_reviews2 = joindre_deux_Dataframe(df1=payments_orders,df2=ensemble_avis_commandes_olist)
order_reviews2 = order_reviews2.drop(columns=['identifiant_avis','titre_commentaire_avis','date_creation_avis','timestamp_reponse_avis'])

# %%
order_reviews2.head()
# Out:
#                identifiant_commande type_paiement  valeur_paiement  \
# 0  b81ef226f3fe1789b1e8b2acac839d17   credit_card            99.33
# 1  a9810da82917af2d9aefd1278f1dcfa0   credit_card            24.39
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd   credit_card            65.71
# 3  ba78997921bbcdc1373bb41e913ab953   credit_card           107.78
# 4  ba78997921bbcdc1373bb41e913ab953   credit_card           107.78
#
#                  identifiant_client timestamp_achat_commande  score_avis  \
# 0  0a8556ac6be836b46b3e89920d59291c      2018-04-25 22:01:49           1
# 1  f2c7fc58a9de810828715166c672f10a      2018-06-26 11:01:38           5
# 2  25b14b69de0b6e184ae6fe2755e478f9      2017-12-12 11:19:55           5
# 3  7a5d8efaaa1081f800628c30d2b0728f      2017-12-06 12:04:06           5
# 4  7a5d8efaaa1081f800628c30d2b0728f      2017-12-06 12:04:06           5
#
#                             message_commentaire_avis
# 0  Produto com qualidade ruim, amassado e descasc...
# ...

# %%
order_reviews2 = order_reviews2.dropna()

# %%
order_reviews2.head()
# Out:
#                identifiant_commande type_paiement  valeur_paiement  \
# 0  b81ef226f3fe1789b1e8b2acac839d17   credit_card            99.33
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd   credit_card            65.71
# 6  298fcdf1f73eb413e4d26d01b25bc1cd   credit_card            96.12
# 7  771ee386b001f06208a7419e4fc1bbd7   credit_card            81.16
# 9  1f78449c87a54faf9e96e88ba1491fa9   credit_card           341.09
#
#                  identifiant_client timestamp_achat_commande  score_avis  \
# 0  0a8556ac6be836b46b3e89920d59291c      2018-04-25 22:01:49           1
# 2  25b14b69de0b6e184ae6fe2755e478f9      2017-12-12 11:19:55           5
# 6  a24e6f72471e9dbafcb292bc318f4859      2018-05-07 13:20:41           5
# 7  206c0fcc717333d169ff95933fb47341      2017-06-23 13:11:27           5
# 9  68c9dafdf193586c290b19c71541357a      2018-07-22 14:07:35           5
#
#                             message_commentaire_avis
# 0  Produto com qualidade ruim, amassado e descasc...
# ...

# %%
order_geolocation = joindre_deux_Dataframe(df1=order_reviews2,df2=customer_geolocation)

# %%
order_geolocation.head()
# Out:
#                identifiant_commande type_paiement  valeur_paiement  \
# 0  b81ef226f3fe1789b1e8b2acac839d17   credit_card            99.33
# 1  b81ef226f3fe1789b1e8b2acac839d17   credit_card            99.33
# 2  b81ef226f3fe1789b1e8b2acac839d17   credit_card            99.33
# 3  b81ef226f3fe1789b1e8b2acac839d17   credit_card            99.33
# 4  b81ef226f3fe1789b1e8b2acac839d17   credit_card            99.33
#
#                  identifiant_client timestamp_achat_commande  score_avis  \
# 0  0a8556ac6be836b46b3e89920d59291c      2018-04-25 22:01:49           1
# 1  0a8556ac6be836b46b3e89920d59291c      2018-04-25 22:01:49           1
# 2  0a8556ac6be836b46b3e89920d59291c      2018-04-25 22:01:49           1
# 3  0a8556ac6be836b46b3e89920d59291c      2018-04-25 22:01:49           1
# 4  0a8556ac6be836b46b3e89920d59291c      2018-04-25 22:01:49           1
#
#                             message_commentaire_avis  \
# 0  Produto com qualidade ruim, amassado e descasc...
# ...

# %%
# order_geolocation.isna().sum()

# %%
product_orders3 = joindre_deux_Dataframe(df1=joindre_deux_Dataframe(
    df1 = joindre_deux_Dataframe(df1=ensemble_produits_olist,df2=ensemble_articles_commandes_olist),
    df2 = traduction_nom_categorie_produit),df2=payments_orders )
product_orders3 = product_orders3.drop(columns=['longueur_nom_produit',
                                                'longueur_description_produit',
                                                'quantite_photos_produit',
                                                'poids_produit_g',
                                                'longueur_produit_cm',
                                                'hauteur_produit_cm',
                                                'largeur_produit_cm',
                                                'identifiant_article_commande',
                                                'identifiant_vendeur',
                                                'date_limite_expedition',
                                                'prix',
                                                'valeur_fret'
                                                ])

# %%
product_orders3.head()
# Out:
#                 identifiant_produit  nom_categorie_produit  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#                identifiant_commande nom_categorie_produit_anglais  \
# 0  e17e4f88e31525f7deef66779844ddce                     perfumery
# 1  5236307716393b7114b53ee991f36956                           art
# 2  01f66e58769f84129811d43eefd187fb                sports_leisure
# 3  143d00a4f2dde4e0364ee1821577adb3                          baby
# 4  86cafb8794cb99a9b1b77fc8e48fbbbb                    housewares
#
#   type_paiement  valeur_paiement                identifiant_client  \
# 0    debit_card            18.30  f8a3e963a310aa58b60a5b1fed5bceb5
# 1       voucher           265.99  03fc97548af8f58fefc768d12b546c9c
# ...

# %%
product_orders3.isna().sum()
# Out:
# identifiant_produit              0
# nom_categorie_produit            0
# identifiant_commande             0
# nom_categorie_produit_anglais    0
# type_paiement                    0
# valeur_paiement                  0
# identifiant_client               0
# timestamp_achat_commande         0
# dtype: int64

# %% [markdown]
# <!-- ensemble_clients_olis -->

# %%
ensemble_clients_olist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   identifiant_client          99441 non-null  object
#  1   identifiant_unique_client   99441 non-null  object
#  2   prefixe_code_postal_client  99441 non-null  object
#  3   ville_client                99441 non-null  object
#  4   etat_client                 99441 non-null  object
# dtypes: object(5)
# memory usage: 3.8+ MB

# %%
#Conversion des codes postaux en chaine de caractère.
ensemble_clients_olist['prefixe_code_postal_client'] = ensemble_clients_olist['prefixe_code_postal_client'].astype(str)

# %% [markdown]
# ensemble_geolocalisation_olist

# %%
ensemble_geolocalisation_olist[ensemble_geolocalisation_olist.duplicated() == True]
# Out:
#         prefixe_code_postal_client  latitude_geolocalisation  \
# 15                            1046                -23.546081
# 44                            1046                -23.546081
# 65                            1046                -23.546081
# 66                            1009                -23.546935
# 67                            1046                -23.546081
# ...                            ...                       ...
# 1000153                      99970                -28.343273
# 1000154                      99950                -28.070493
# 1000159                      99900                -27.877125
# 1000160                      99950                -28.071855
# 1000162                      99950                -28.070104
#
#          longitude_geolocalisation ville_geolocalisation etat_geolocalisation
# 15                      -46.644820             sao paulo                   SP
# ...

# %% [markdown]
# Vérification des valeurs aberrantes.

# %%
# ensemble_geolocalisation_olist = ensemble_geolocalisation_olist.drop_duplicates()

# %%
# ensemble_geolocalisation_olist['prefixe_code_postal_geolocalisation'] = ensemble_geolocalisation_olist['prefixe_code_postal_geolocalisation'].astype(str)

# %%
# ensemble_geolocalisation_olist.info()

# %% [markdown]
# ensemble_articles_commandes_olist

# %%
# ensemble_articles_commandes_olist.info()

# %%
# ensemble_articles_commandes_olist['identifiant_article_commande'] = ensemble_articles_commandes_olist['identifiant_article_commande'].astype(str)

# %%
# ensemble_articles_commandes_olist.describe()

# %%
# fig = px.box(ensemble_articles_commandes_olist, y="prix")
# fig.show()

# %%
# fig = px.box(ensemble_produits_olist, y="poids_produit_g")
# fig.show()

# %%
# fig = px.box(ensemble_articles_commandes_olist, y="valeur_fret")
# fig.show()

# %%
# ensemble_produits_olist.duplicated().sum()

# %%
# ensemble_produits_olist.info()

# %% [markdown]
# ensemble_paiements_commandes_olist

# %%
# ensemble_paiements_commandes_olist.describe()

# %%
# ensemble_paiements_commandes_olist.isna().sum()

# %%
# ensemble_paiements_commandes_olist.duplicated().sum()

# %%
# fig = px.box(ensemble_paiements_commandes_olist, y="valeur_paiement")
# fig.show()

# %%
# comptabilité = pd.merge(ensemble_articles_commandes_olist,ensemble_paiements_commandes_olist,how='inner')

# %%
# comptabilité

# %%
# fig = px.imshow(comptabilité[['prix','valeur_fret','sequence_paiement','versements_paiement','valeur_paiement']].corr(), text_auto=True)
# fig.show()

# %%
# comptabilité_sub = créer_un_sous_ensemble_de_données(data=comptabilité,target='prix')

# %%
# comptabilité_sub

# %%
# comptabilité['prix']

# %%
# fig = px.box(comptabilité, y="prix")
# fig.show()

# %%
# fig = px.box(comptabilité_sub, y="prix")
# fig.show()

# %%
# prédiction_prix_train = entrainer_régression_linéaire_et_prédire(data=comptabilité_sub,target='prix',feature='valeur_paiement')

# %%
# prédiction_prix_test = tester_régression_linéaire_et_prédire(data=comptabilité_sub,target='prix',feature='valeur_paiement',coeffs=prédiction_prix_train[0])

# %%
# comptabilité

# %%
# fig = px.imshow(comptabilité[['prix','valeur_fret','sequence_paiement','versements_paiement','valeur_paiement']].corr(), text_auto=True)
# fig.show()

# %% [markdown]
# Traitement 'valeur_paiement'

# %%
# fig = px.box(comptabilité, y="prix")
# fig.show()

# %%
# comptabilité.isna().sum()

# %%
# indice_dispertion_positive2 = 1.5 * (comptabilité['valeur_paiement'].quantile(q=0.75 - 0.25))
# indice_dispertion_négative2 = -1.5 * (comptabilité['valeur_paiement'].quantile(q=0.75 - 0.25))

# %%
# comptabilité_sub_2 = comptabilité[~((comptabilité['valeur_paiement'] > indice_dispertion_positive2) | (comptabilité['valeur_paiement'] < indice_dispertion_négative2))]

# %%
# fig = px.box(comptabilité_sub_2, y="valeur_paiement")
# fig.show()

# %%
# x2 = comptabilité_sub_2['prix'].to_numpy()
# y2 = comptabilité_sub_2['valeur_paiement'].to_numpy()

# %%
# X_train2, X_test2, y_train2, y_test2 = train_test_split(x2, y2, test_size=0.2, random_state=42)

# %%
# coeffs2 = np.polyfit(X_train2, y_train2, 1)
# y_pred2 = np.polyval(coeffs2,X_train2)

# %%
# np.mean(y_train2-y_pred2)**2

# %%
# fig = px.scatter(
#     x=X_train2, y=y_pred2, opacity=0.65,
#     trendline='ols', trendline_color_override='darkblue'
# )
# fig.show()

# %%
# y_pred_test2 = np.polyval(coeffs2,X_test2)

# %%
# np.mean(y_test2-y_pred_test2)**2

# %%
# fig = px.scatter(
#     x=X_test2, y=y_pred_test2, opacity=0.65,
#     trendline='ols', trendline_color_override='darkblue'
# )
# fig.show()

# %%
# pd.DataFrame(y_pred_test2)

# %%
# condition2 = (comptabilité['valeur_paiement'] > indice_dispertion_positive2) | (comptabilité['valeur_paiement'] < indice_dispertion_négative2)
# comptabilité.loc[condition2, 'valeur_paiement'] = np.nan

# %%
# predictions = np.polyval(coeffs, comptabilité['prix'])
# predictions = pd.Series(predictions)
# comptabilité.fillna({'valeur_paiement': predictions}, inplace=True)

# %%
# comptabilité

# %%
# fig = px.box(comptabilité, y="valeur_paiement")
# fig.show()
